# %%
#Analysis of Youtube videos trend with an additional variable Subscribers

# %% [markdown]
# To learn more about this dataset visit https://www.kaggle.com/sgonkaggle/youtube-trend-with-subscriber

# %%
from platform import python_version
print(python_version())
# Out:
# 3.7.1

# %%
import pandas as pd

# %% [markdown]
# The pandas df.describe()and df.info()functions are normally used
# as a first step in the EDA process. However, it only gives a very
# basic overview of the data and doesn’t help much in the case of
# large data sets. The Pandas Profiling function, on the other hand,
# displays a lot of information with a single line of code and that
# too in an interactive HTML report.

# %%
import pandas_profiling

# %% [markdown]
# Read data from file USvideos_modified.csv

# %%
df  = pd.read_csv('/Users/navi/Desktop/JobAgain!/Kaggle/YoutubeTrending-WithSubscriber/USvideos_modified.csv')
pandas_profiling.ProfileReport(df)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...
